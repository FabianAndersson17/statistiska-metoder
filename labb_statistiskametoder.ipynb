# %% [markdown]
# # Uppgift 1

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings #used to ignore displot warning
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1.

# %% [markdown]
# ### 1

# %%
samp_5 = np.random.randint(4,8,5)
samp_5, samp_5.mean()
# Out:
# (array([6, 7, 5, 6, 7]), 6.2)

# %% [markdown]
# ### 2

# %%
#Define an array for 20,000 samples per each sample size 
samples_10 = np.zeros(10000) 
samples_20 = np.zeros(20000) 
samples_30 = np.zeros(30000) 
samples_40 = np.zeros(40000) 
samples_50 = np.zeros(50000)
#Defining parameters from our population distribution
mu, sigma = 5.5, np.sqrt(1.25)

# %%
#Defining parameters from our population distribution
mu, sigma = 5.5, np.sqrt(1.25)
#Creating for loop for sample size 2
for x in range(10000):
    sample = np.random.normal(mu, sigma, 10)
    x_bar_10 = sample.mean()
    samples_10[x] = np.sqrt(10)*(x_bar_10-5.5)/np.sqrt(1.25)
#Creating for loop for sample size 5
for a in range(20000):
    sample = np.random.normal(mu, sigma, 20)
    x_bar_20 = sample.mean()
    samples_20[a] = np.sqrt(20)*(x_bar_20-5.5)/np.sqrt(1.25)
#Creating for loop for sample size 10
for b in range(30000):
    sample = np.random.normal(mu, sigma, 30)
    x_bar_30 = sample.mean()
    samples_30[b] = np.sqrt(30)*(x_bar_30-5.5)/np.sqrt(1.25)
#Creating for loop for sample size 100
for c in range(40000):
    sample = np.random.normal(mu, sigma, 40)
    x_bar_40 = sample.mean()
    samples_40[c] = np.sqrt(40)*(x_bar_40-5.5)/np.sqrt(1.25)
#Creating for loop for sample size 250
for d in range(50000):
    sample = np.random.normal(mu, sigma, 50)
    x_bar_50 = sample.mean()
    samples_50[d] = np.sqrt(50)*(x_bar_50-5.5)/np.sqrt(1.25)

# %%
#Combining arrays into a dataframe to plot
populationTestLsit = [samples_10, samples_20, samples_30, samples_40, samples_50]
#Plotting Distributions
plt.figure(figsize=(20,10))
# sns.distplot(populationTestLsit[0])
# sns.distplot(populationTestLsit[1])
# sns.distplot(populationTestLsit[2])
# sns.distplot(populationTestLsit[3])
sns.distplot(populationTestLsit[4])
# plt.legend(populationTestLsit[0], fontsize=20)
plt.show()

# %% [markdown]
# ### 3

# %%
print(f"My fårs fram av x*P(X=x) detta görs för alla x sedan adderas dem ihop. 4*(1/4)+5*(1/4)+6*(1/4)+7*(1/4) = {(4*(1/4)+ 5*(1/4)+6*(1/4)+7*(1/4))}")
# Out:
# My fårs fram av x*P(X=x) detta görs för alla x sedan adderas dem ihop. 4*(1/4)+5*(1/4)+6*(1/4)+7*(1/4) = 5.5

# %% [markdown]
# ### 4

# %%
print(f"My fårs fram av roten ur (x^2*P(X=x)-my^2) detta görs för alla x sedan adderas dem ihop. √4^2*(1/4)+5^2*(1/4)+6^2*(1/4)+7^2*(1/4)-4*(1/4)+5*(1/4)+6*(1/4)+7*(1/4) = {np.sqrt(((4**2)*(1/4)+ (5**2)*(1/4)+(6**2)*(1/4)+(7**2)*(1/4))-5.5**2)}")
# Out:
# My fårs fram av roten ur (x^2*P(X=x)-my^2) detta görs för alla x sedan adderas dem ihop. √4^2*(1/4)+5^2*(1/4)+6^2*(1/4)+7^2*(1/4)-4*(1/4)+5*(1/4)+6*(1/4)+7*(1/4) = 1.118033988749895

# %% [markdown]
# ### 5

# %%
print("Fördelingen blir mer normalfördelad om stickprovet är tillräckligt stort")
# Out:
# Fördelingen blir mer normalfördelad om stickprovet är tillräckligt stort

# %% [markdown]
# ### 6

# %%
iterationVar = 0
x_bar_mean_list = []
placeholder = np.zeros(1000)
for _ in range(1000):
    x_bar = np.random.randint(4,8,50)
    x_bar_mean = x_bar.mean()
    x_bar_mean_list.append(x_bar_mean)

for x in x_bar_mean_list:
    placeholder[x] = x_bar_mean_list(iterationVar) + 1.96 * (0.1118/(np.sqrt(50)))
    iterationVar+=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\FABIAN~1\AppData\Local\Temp/ipykernel_2096/749205711.py in <module>
#       8
#       9 for x in x_bar_mean_list:
# ---> 10     placeholder[x] = x_bar_mean_list(iterationVar) + 1.96 * (0.1118/(np.sqrt(50)))
#      11     iterationVar+=1
#
# TypeError: 'list' object is not callable
